# %% [markdown]
# ---
# title: "Youth Power Karnataka: Vector Analysis"
# author: "Tailapa"
# format:
#   html:
#     theme: cosmo
#     toc: true
#     code-fold: true
#     code-summary: "View the Logic Vector"
#     self-contained: true
# execute:
#   echo: false
# ---
